# %% [markdown]
# ##                          1.The Problem
# In mid 2017, maize prices in Kenya shot through the roof. Being a staple food in most part of the country, this shortage  caused a grave crisis. Apparently the crisis was caused by lack of rainfall in major maize producing regions like Eldoret and this led to large scale hoarding by the traders. A 90kg bag of maize which caused ksh.3000 was now KSh 6,750, the highest in the country's history. The crisis caused political tension in the country with the oppostion party accusing the governmnet of failing to plan for poor harvests. The government resorted to importation of maize from Mexico.
#
# - Maize shortage, How did we get here? : https://www.capitalfm.co.ke/business/2017/06/maize-shortage-how-did-we-get-here/
# - Kenya's food crisis:  http://www.climatechangenews.com/2017/07/26/kenyas-food-crisis-drought-raises-prices-political-tensions/
#
# <img src="maize.png">
#
#
# Today I would like to compare the maize prices in the East African markets,try to find out how Kenya compares to its neighbours and later on make a prediction of the maize prices in the country for the next several months.
#
# I am going to use the data from RATIN (http://ratin.net/site/market) which is the Regional Agricultural Trade Intelligence Network for the East African Community
#
#
#
#   # Analysis
#
#
# Descriptive
#        "seeks to summarize a characteristic of a set of data"
#
#     how does Kenya compare to other countries?
#     Which city in Kenya has the highest maize prices?
#     What is the average price of maize in Kenya?
#     Which country has the highest and lowest prices.
#     Which month was the price of maize lowest in Kenya?
#     ...
#
# Exploratory & Inferential
#       "analyze the data to see if there are patterns, trends, or relationships between variables" (hypothesis generating)
#
#     Is there a large difference between High and Low prices of Maize in a day?
#     What is the trend of onion price across days or months in Kenya?
#
#     ...
#
# Predictive
#
#     What is the price of maize  likely to be next day?
#     What is the price of maize likely to be next month?
#
#     ...
#
# Causal
#    asks whether changing one factor will change another factor in a population - to establish a causal link"
#
#     ...
#
# Mechanistic
#
#   "establish how the change in one factor results in change in another factor in a population - to determine the exact          mechanism"
